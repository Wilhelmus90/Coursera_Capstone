# %%
import requests # library to handle requests
import pandas as pd # library for data analsysis
import numpy as np # library to handle data in a vectorized manner
import random # library for random number generation

# !conda install -c conda-forge geopy --yes 
from geopy.geocoders import Nominatim # module to convert an address into latitude and longitude values

# libraries for displaying images
from IPython.display import Image 
from IPython.core.display import HTML 
    
# tranforming json file into a pandas dataframe library
from pandas.io.json import json_normalize

# !conda install -c conda-forge folium=0.5.0 --yes
import folium # plotting library

print('Folium installed')
print('Libraries imported.')
# Out:
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Solving environment: done
#
#
# ==> WARNING: A newer version of conda exists. <==
#   current version: 4.5.11
#   latest version: 4.7.10
#
# Please update conda by running
#
#     $ conda update -n base -c defaults conda
#
#
#
# # All requested packages already installed.
#
# Folium installed
# Libraries imported.

# %%
CLIENT_ID = 'KSMKSXS2S2KQ43DKCTPOM53JRAF03WPHS1KQA0AO5H4XODUQ' # your Foursquare ID
CLIENT_SECRET = '532IXFRDSOZC3S4QZ4R4O14YZO3QFDA2SDHO21DW4YFS0ORC' # your Foursquare Secret
VERSION = '20180604'
LIMIT = 30
print('Your credentails:')
print('CLIENT_ID: ' + CLIENT_ID)
print('CLIENT_SECRET:' + CLIENT_SECRET)
# Out:
# Your credentails:
# CLIENT_ID: KSMKSXS2S2KQ43DKCTPOM53JRAF03WPHS1KQA0AO5H4XODUQ
# CLIENT_SECRET:532IXFRDSOZC3S4QZ4R4O14YZO3QFDA2SDHO21DW4YFS0ORC

# %%
address = 'Schiphol'

geolocator = Nominatim(user_agent="foursquare_agent")
location = geolocator.geocode(address)
latitude = location.latitude
longitude = location.longitude
print(latitude, longitude)
# Out:
# 52.3080392 4.7621975

# %%
search_query = 'financial'
radius = 25000
print(search_query + ' .... OK!')
search_query = 'banking'
radius = 25000
print(search_query + ' .... OK!')
search_query = 'investment'
radius = 25000
print(search_query + ' .... OK!')
search_query = 'trading'
radius = 25000
print(search_query + ' .... OK!')
# Out:
# financial .... OK!
# banking .... OK!
# investment .... OK!
# trading .... OK!

# %%
url = 'https://api.foursquare.com/v2/venues/search?client_id={}&client_secret={}&ll={},{}&v={}&query={}&radius={}&limit={}'.format(CLIENT_ID, CLIENT_SECRET, latitude, longitude, VERSION, search_query, radius, LIMIT)
url
# Out:
# 'https://api.foursquare.com/v2/venues/search?client_id=KSMKSXS2S2KQ43DKCTPOM53JRAF03WPHS1KQA0AO5H4XODUQ&client_secret=532IXFRDSOZC3S4QZ4R4O14YZO3QFDA2SDHO21DW4YFS0ORC&ll=52.3080392,4.7621975&v=20180604&query=trading&radius=25000&limit=30'

# %%
results = requests.get(url).json()
results
# Out:
# {'meta': {'code': 200, 'requestId': '5d40a37a308b980025bcb98e'},
#  'response': {'venues': [{'id': '4e636460cc3f7bb374132d83',
#     'name': 'Hardware shop @ Aljunied (Power-J Trading Pte Ltd)',
#     'location': {'address': '86 Lorong 25A Geylang',
#      'crossStreet': 'Off Sims Avenue',
#      'lat': 52.345276451477034,
#      'lng': 4.768195152282715,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.345276451477034,
#        'lng': 4.768195152282715}],
#      'distance': 4165,
#      'postalCode': '388263',
#      'cc': 'NL',
#      'city': 'Singapore',
#      'country': 'Nederland',
#      'formattedAddress': ['86 Lorong 25A Geylang (Off Sims Avenue)',
#       '388263 Singapore',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4de6293a45dda52a06059842',
#     'name': 'Marine Trading International',
#     'location': {'lat': 52.271406,
#      'lng': 4.776675,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.271406,
#        'lng': 4.776675}],
#      'distance': 4195,
#      'cc': 'NL',
#      'city': 'Aalsmeer',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Aalsmeer', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4d89b70299c2a1cd667a80d7',
#     'name': 'Robel Trading Telecom Aalsmeer',
#     'location': {'lat': 52.26739176527938,
#      'lng': 4.749297210266143,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.26739176527938,
#        'lng': 4.749297210266143}],
#      'distance': 4609,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d122951735',
#       'name': 'Electronics Store',
#       'pluralName': 'Electronics Stores',
#       'shortName': 'Electronics',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5d19ab7fb55cb800231335a3',
#     'name': 'STX Commodities Trading Desk',
#     'location': {'address': 'Vijzelstraat 79',
#      'lat': 52.364138,
#      'lng': 4.892859,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.364138,
#        'lng': 4.892859}],
#      'distance': 10862,
#      'postalCode': '1017 HG',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Vijzelstraat 79',
#       '1017 HG Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '56aa371be4b08b9a8d573517',
#       'name': 'Business Center',
#       'pluralName': 'Business Centers',
#       'shortName': 'Business Center',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4d934e6a62ad5481e7be7e4b',
#     'name': 'Maximum Trading B.V.',
#     'location': {'address': 'Amstelveenseweg 645',
#      'lat': 52.331885725,
#      'lng': 4.8574798999999995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.331885725,
#        'lng': 4.8574798999999995}],
#      'distance': 7005,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Amstelveenseweg 645', 'Amsterdam', 'Nederland']},
#     'categories': [],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5be48a25811045002c66baac',
#     'name': 'Mollers Trading & Services',
#     'location': {'address': 'Rosa Spierstraat 65',
#      'lat': 52.296101,
#      'lng': 4.659543,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.296101,
#        'lng': 4.659543}],
#      'distance': 7113,
#      'postalCode': '2135 TP',
#      'cc': 'NL',
#      'city': 'Hoofddorp',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Rosa Spierstraat 65',
#       '2135 TP Hoofddorp',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124951735',
#       'name': 'Automotive Shop',
#       'pluralName': 'Automotive Shops',
#       'shortName': 'Automotive',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/automotive_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '513887756'},
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5d14c461557df100239f32a1',
#     'name': 'BTinvestment Trading',
#     'location': {'address': 'Gustav Mahlerlaan 25',
#      'lat': 52.336525,
#      'lng': 4.874767,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.336525,
#        'lng': 4.874767}],
#      'distance': 8289,
#      'postalCode': '1082 MK',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Gustav Mahlerlaan 25',
#       '1082 MK Amsterdam',
#       'Nederland']},
#     'categories': [],
#     'venuePage': {'id': '551260434'},
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '57167f4b498ea9f4977e6f14',
#     'name': 'Road Trip Trading',
#     'location': {'lat': 52.266761,
#      'lng': 4.650915,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.266761,
#        'lng': 4.650915}],
#      'distance': 8862,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1df931735',
#       'name': 'BBQ Joint',
#       'pluralName': 'BBQ Joints',
#       'shortName': 'BBQ',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/bbqalt_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '54cc35be498ed9d4e725c990',
#     'name': 'New Trend Trading Company BV',
#     'location': {'address': 'Spaarneweg 75',
#      'lat': 52.334108,
#      'lng': 4.627609899999999,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.334108,
#        'lng': 4.627609899999999}],
#      'distance': 9606,
#      'postalCode': '2142 EP',
#      'cc': 'NL',
#      'city': 'Cruquius',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Spaarneweg 75', '2142 EP Cruquius', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d1ed941735',
#       'name': 'Spa',
#       'pluralName': 'Spas',
#       'shortName': 'Spa',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/spa_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '54a1471f498e6de3ba9209f0',
#     'name': 'GroupM Trading',
#     'location': {'address': 'Karperstraat 8',
#      'lat': 52.347288947106954,
#      'lng': 4.8560889325018435,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.347288947106954,
#        'lng': 4.8560889325018435}],
#      'distance': 7738,
#      'postalCode': '1075 KZ',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Karperstraat 8', '1075 KZ Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4de78322887710a065b84bde',
#     'name': 'Titan Arbitrage Trading',
#     'location': {'address': 'Weteringschans 26',
#      'lat': 52.360310378777875,
#      'lng': 4.886610566304529,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.360310378777875,
#        'lng': 4.886610566304529}],
#      'distance': 10270,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Weteringschans 26', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4f7f20fbe4b0340b448e1cd3',
#     'name': 'Network4Cars Trading B.V.',
#     'location': {'lat': 52.25664093863679,
#      'lng': 4.63192348458904,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.25664093863679,
#        'lng': 4.63192348458904}],
#      'distance': 10556,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d174941735',
#       'name': 'Coworking Space',
#       'pluralName': 'Coworking Spaces',
#       'shortName': 'Coworking Space',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/office_coworkingspace_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4ec2232c5c5c3d470dc41e0f',
#     'name': 'Duinrand Trading',
#     'location': {'address': 'Havenstraat 87',
#      'crossStreet': 'Suite 118',
#      'lat': 52.347821414339556,
#      'lng': 4.625667853509281,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.347821414339556,
#        'lng': 4.625667853509281}],
#      'distance': 10290,
#      'postalCode': '2102 LB',
#      'cc': 'NL',
#      'city': 'Heemstede',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Havenstraat 87 (Suite 118)',
#       '2102 LB Heemstede',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d125941735',
#       'name': 'Tech Startup',
#       'pluralName': 'Tech Startups',
#       'shortName': 'Tech Startup',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '33102063'},
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4e1eb360ae60cd553de9b3d7',
#     'name': 'Kenwell Trading',
#     'location': {'address': 'Oosteinde 7-9-11',
#      'lat': 52.359467,
#      'lng': 4.902139,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.359467,
#        'lng': 4.902139}],
#      'distance': 11108,
#      'postalCode': '1017 WT',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Oosteinde 7-9-11',
#       '1017 WT Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4c9b1670db10b60c8125986d',
#     'name': 'Percival Trading Partners',
#     'location': {'lat': 52.376242,
#      'lng': 4.887394,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.376242,
#        'lng': 4.887394}],
#      'distance': 11407,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d100951735',
#       'name': 'Pet Store',
#       'pluralName': 'Pet Stores',
#       'shortName': 'Pet Store',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/pet_store_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '536521da498ebebcd5fa54f5',
#     'name': 'POP TRADING COMPANY STORE',
#     'location': {'address': 'Houkopersdwarsstraat 6',
#      'lat': 52.368922,
#      'lng': 4.902289,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.368922,
#        'lng': 4.902289}],
#      'distance': 11692,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Houkopersdwarsstraat 6', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b3d',
#       'name': 'Pop-Up Shop',
#       'pluralName': 'Pop-Up Shops',
#       'shortName': 'Pop-Up Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '598ddf5cc0f1632f708220fe',
#     'name': 'Pop Trading Company',
#     'location': {'address': 'Brouwersgracht 75A',
#      'lat': 52.37993,
#      'lng': 4.888984,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.37993,
#        'lng': 4.888984}],
#      'distance': 11763,
#      'postalCode': '1015 GC',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Brouwersgracht 75A',
#       '1015 GC Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d103951735',
#       'name': 'Clothing Store',
#       'pluralName': 'Clothing Stores',
#       'shortName': 'Apparel',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/apparel_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4e1abd5da8097d08b24c4ad2',
#     'name': 'Caerus Trading HQ',
#     'location': {'address': 'Beursplein 5',
#      'lat': 52.374306,
#      'lng': 4.896534,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.374306,
#        'lng': 4.896534}],
#      'distance': 11742,
#      'postalCode': '1012 JW',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Beursplein 5', '1012 JW Amsterdam', 'Nederland']},
#     'categories': [],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4e268ac5e4cd60a2c6268812',
#     'name': 'Bitasco Trading',
#     'location': {'address': 'gyroscoopweg 102',
#      'lat': 52.40371025702295,
#      'lng': 4.83825214211878,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.40371025702295,
#        'lng': 4.83825214211878}],
#      'distance': 11838,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['gyroscoopweg 102', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5044a67ce4b0a10508092139',
#     'name': 'Holwa Trading Company',
#     'location': {'lat': 52.374020642531676,
#      'lng': 4.901452335272934,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.374020642531676,
#        'lng': 4.901452335272934}],
#      'distance': 11985,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4ca3ad557f84224b0fddc658',
#     'name': 'HMC Trading',
#     'location': {'address': 'Wateringweg 15',
#      'lat': 52.396743,
#      'lng': 4.65952849,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.396743,
#        'lng': 4.65952849}],
#      'distance': 12092,
#      'postalCode': '2031EK',
#      'cc': 'NL',
#      'city': 'Haarlem',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Wateringweg 15', '2031EK Haarlem', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d130941735',
#       'name': 'Building',
#       'pluralName': 'Buildings',
#       'shortName': 'Building',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '58ddfc7a0e0a1e6dd88021c9',
#     'name': 'Adbulco Trading BV',
#     'location': {'address': 'De Ruijterplein 4',
#      'lat': 52.38021,
#      'lng': 4.61688,
#      'labeledLatLngs': [{'label': 'display', 'lat': 52.38021, 'lng': 4.61688}],
#      'distance': 12736,
#      'postalCode': '2014 AS',
#      'cc': 'NL',
#      'city': 'Haarlem',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['De Ruijterplein 4',
#       '2014 AS Haarlem',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d112951735',
#       'name': 'Hardware Store',
#       'pluralName': 'Hardware Stores',
#       'shortName': 'Hardware',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/hardware_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '51519c0de4b005a46b8fc8ec',
#     'name': 'Sd Trading',
#     'location': {'lat': 52.38196290736983,
#      'lng': 4.921689229097177,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.38196290736983,
#        'lng': 4.921689229097177}],
#      'distance': 13614,
#      'cc': 'NL',
#      'country': 'Nederland',
#      'formattedAddress': ['Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '61928988'},
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4d01ea6f3fd4224b8fffb377',
#     'name': 'Weide Trading',
#     'location': {'address': 'Kruisbaak 11a',
#      'lat': 52.253236,
#      'lng': 4.571199,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.253236,
#        'lng': 4.571199}],
#      'distance': 14367,
#      'cc': 'NL',
#      'city': 'Lisserbroek',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Kruisbaak 11a', 'Lisserbroek', 'Nederland']},
#     'categories': [],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '57889e85498e1129b17b859f',
#     'name': 'Bitex Trading BV',
#     'location': {'address': 'Saltholm 30',
#      'lat': 52.4323692,
#      'lng': 4.8269601,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.4323692,
#        'lng': 4.8269601}],
#      'distance': 14523,
#      'postalCode': '1506 BT',
#      'cc': 'NL',
#      'city': 'Zaandam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Saltholm 30', '1506 BT Zaandam', 'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b26',
#       'name': 'Fabric Shop',
#       'pluralName': 'Fabric Shops',
#       'shortName': 'Fabric Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '4d8372f8e83fa14325da4ca1',
#     'name': 'Van der Ham trading',
#     'location': {'address': 'Grevelingstraat 71',
#      'lat': 52.25325473974714,
#      'lng': 4.565286289868614,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.25325473974714,
#        'lng': 4.565286289868614}],
#      'distance': 14732,
#      'postalCode': '2161 WE',
#      'cc': 'NL',
#      'city': 'Lisse',
#      'state': 'Zuid-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Grevelingstraat 71', '2161 WE Lisse', 'Nederland']},
#     'categories': [{'id': '5032833091d4c4b30a586d60',
#       'name': 'Motorcycle Shop',
#       'pluralName': 'Motorcycle Shops',
#       'shortName': 'Motorcycle Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/motorcycle_',
#        'suffix': '.png'},
#       'primary': True}],
#     'venuePage': {'id': '50689880'},
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5403ec5c498ed907856ffa9c',
#     'name': '020TRADING',
#     'location': {'address': 'Marathonweg 35-1',
#      'crossStreet': 'Olympiaweg',
#      'lat': 52.34788131713867,
#      'lng': 4.862458229064941,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.34788131713867,
#        'lng': 4.862458229064941}],
#      'distance': 8136,
#      'postalCode': '1076 TA',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Marathonweg 35-1 (Olympiaweg)',
#       '1076 TA Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '52f2ab2ebcbc57f1066b8b36',
#       'name': 'IT Services',
#       'pluralName': 'IT Services',
#       'shortName': 'IT Services',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/technology_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '56d5a867498e679defdb9879',
#     'name': 'DrBeyk / Mobiele Fietsenmaker Amsterdam',
#     'location': {'address': 'Uiterwaardenstraat 171',
#      'lat': 52.34276,
#      'lng': 4.90148,
#      'labeledLatLngs': [{'label': 'display', 'lat': 52.34276, 'lng': 4.90148}],
#      'distance': 10234,
#      'postalCode': '1079 CL',
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Uiterwaardenstraat 171',
#       '1079 CL Amsterdam',
#       'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d115951735',
#       'name': 'Bike Shop',
#       'pluralName': 'Bike Shops',
#       'shortName': 'Bike Shop',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/shops/bikeshop_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '514b4737e4b0e87606794d0e',
#     'name': 'Bubbles from Budepest ww.4-trading.com',
#     'location': {'address': 'Van Ostadestraat 154',
#      'lat': 52.352162,
#      'lng': 4.893108,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.352162,
#        'lng': 4.893108}],
#      'distance': 10170,
#      'cc': 'NL',
#      'city': 'Amsterdam',
#      'state': 'Noord-Holland',
#      'country': 'Nederland',
#      'formattedAddress': ['Van Ostadestraat 154', 'Amsterdam', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d14b941735',
#       'name': 'Winery',
#       'pluralName': 'Wineries',
#       'shortName': 'Winery',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/food/winery_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False},
#    {'id': '5118d322e4b05a0ebd0679e3',
#     'name': 'Easy Hardware Trading',
#     'location': {'address': 'Corridor 12',
#      'lat': 52.178174,
#      'lng': 4.990995,
#      'labeledLatLngs': [{'label': 'display',
#        'lat': 52.178174,
#        'lng': 4.990995}],
#      'distance': 21265,
#      'cc': 'NL',
#      'city': 'Breukelen',
#      'state': 'Utrecht',
#      'country': 'Nederland',
#      'formattedAddress': ['Corridor 12', 'Breukelen', 'Nederland']},
#     'categories': [{'id': '4bf58dd8d48988d124941735',
#       'name': 'Office',
#       'pluralName': 'Offices',
#       'shortName': 'Office',
#       'icon': {'prefix': 'https://ss3.4sqi.net/img/categories_v2/building/default_',
#        'suffix': '.png'},
#       'primary': True}],
#     'referralId': 'v-1564517242',
#     'hasPerk': False}]}}

# %%
# assign relevant part of JSON to venues
venues = results['response']['venues']

# tranform venues into a dataframe
dataframe = json_normalize(venues)
dataframe.head()
# Out:
#                          id  \
# 0  4e636460cc3f7bb374132d83
# 1  4de6293a45dda52a06059842
# 2  4d89b70299c2a1cd667a80d7
# 3  5d19ab7fb55cb800231335a3
# 4  4d934e6a62ad5481e7be7e4b
#
#                                                 name  \
# 0  Hardware shop @ Aljunied (Power-J Trading Pte ...
# 1                       Marine Trading International
# 2                     Robel Trading Telecom Aalsmeer
# 3                       STX Commodities Trading Desk
# 4                               Maximum Trading B.V.
#
#                                           categories    referralId  hasPerk  \
# 0  [{'id': '4bf58dd8d48988d112951735', 'name': 'H...  v-1564517242    False
# 1  [{'id': '4bf58dd8d48988d124941735', 'name': 'O...  v-1564517242    False
# 2  [{'id': '4bf58dd8d48988d122951735', 'name': 'E...  v-1564517242    False
# 3  [{'id': '56aa371be4b08b9a8d573517', 'name': 'B...  v-1564517242    False
# 4                                                 []  v-1564517242    False
#
#         location.address location.crossStreet  location.lat  location.lng  \
# 0  86 Lorong 25A Geylang      Off Sims Avenue     52.345276      4.768195
# 1                    NaN                  NaN     52.271406      4.776675
# 2                    NaN                  NaN     52.267392      4.749297
# 3        Vijzelstraat 79                  NaN     52.364138      4.892859
# 4    Amstelveenseweg 645                  NaN     52.331886      4.857480
#
#                              location.labeledLatLngs  location.distance  \
# 0  [{'label': 'display', 'lat': 52.34527645147703...               4165
# 1  [{'label': 'display', 'lat': 52.271406, 'lng':...               4195
# 2  [{'label': 'display', 'lat': 52.26739176527938...               4609
# 3  [{'label': 'display', 'lat': 52.364138, 'lng':...              10862
# 4  [{'label': 'display', 'lat': 52.331885725, 'ln...               7005
#
#   location.postalCode location.cc location.city location.country  \
# 0              388263          NL     Singapore        Nederland
# 1                 NaN          NL      Aalsmeer        Nederland
# 2                 NaN          NL           NaN        Nederland
# 3             1017 HG          NL     Amsterdam        Nederland
# 4                 NaN          NL     Amsterdam        Nederland
#
#                            location.formattedAddress location.state  \
# 0  [86 Lorong 25A Geylang (Off Sims Avenue), 3882...            NaN
# 1                              [Aalsmeer, Nederland]  Noord-Holland
# 2                                        [Nederland]            NaN
# 3    [Vijzelstraat 79, 1017 HG Amsterdam, Nederland]  Noord-Holland
# 4        [Amstelveenseweg 645, Amsterdam, Nederland]  Noord-Holland
#
#   venuePage.id
# 0          NaN
# 1          NaN
# 2          NaN
# 3          NaN
# 4          NaN

# %%
# keep only columns that include venue name, and anything that is associated with location
filtered_columns = ['name', 'categories'] + [col for col in dataframe.columns if col.startswith('location.')] + ['id']
dataframe_filtered = dataframe.loc[:, filtered_columns]

# function that extracts the category of the venue
def get_category_type(row):
    try:
        categories_list = row['categories']
    except:
        categories_list = row['venue.categories']
        
    if len(categories_list) == 0:
        return None
    else:
        return categories_list[0]['name']

# filter the category for each row
dataframe_filtered['categories'] = dataframe_filtered.apply(get_category_type, axis=1)

# clean column names by keeping only last term
dataframe_filtered.columns = [column.split('.')[-1] for column in dataframe_filtered.columns]

dataframe_filtered

datagoed = dataframe_filtered.drop(['name', 'categories', 'labeledLatLngs', 'cc', 'country', 'formattedAddress', 'address', 'crossStreet', 'postalCode', 'id', 'distance','state'], axis=1)

datagoed
# Out:
#           lat       lng         city
# 0   52.345276  4.768195    Singapore
# 1   52.271406  4.776675     Aalsmeer
# 2   52.267392  4.749297          NaN
# 3   52.364138  4.892859    Amsterdam
# 4   52.331886  4.857480    Amsterdam
# 5   52.296101  4.659543    Hoofddorp
# 6   52.336525  4.874767    Amsterdam
# 7   52.266761  4.650915          NaN
# 8   52.334108  4.627610     Cruquius
# 9   52.347289  4.856089    Amsterdam
# 10  52.360310  4.886611    Amsterdam
# 11  52.256641  4.631923          NaN
# 12  52.347821  4.625668    Heemstede
# 13  52.359467  4.902139    Amsterdam
# 14  52.376242  4.887394          NaN
# 15  52.368922  4.902289    Amsterdam
# 16  52.379930  4.888984    Amsterdam
# 17  52.374306  4.896534    Amsterdam
# 18  52.403710  4.838252    Amsterdam
# 19  52.374021  4.901452          NaN
# 20  52.396743  4.659528      Haarlem
# 21  52.380210  4.616880      Haarlem
# 22  52.381963  4.921689          NaN
# 23  52.253236  4.571199  Lisserbroek
# 24  52.432369  4.826960      Zaandam
# 25  52.253255  4.565286        Lisse
# 26  52.347881  4.862458    Amsterdam
# 27  52.342760  4.901480    Amsterdam
# 28  52.352162  4.893108    Amsterdam
# 29  52.178174  4.990995    Breukelen

# %%
venues_map = folium.Map(location=[latitude, longitude], zoom_start=13) # generate map centred around the Conrad Hotel

# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [latitude, longitude],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(venues_map)

# add the Italian restaurants as blue circle markers
for lat, lng, label in zip(dataframe_filtered.lat, dataframe_filtered.lng, dataframe_filtered.categories):
    folium.features.CircleMarker(
        [lat, lng],
        radius=5,
        color='blue',
        popup=label,
        fill = True,
        fill_color='blue',
        fill_opacity=0.6
    ).add_to(venues_map)

# display map
venues_map
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
print(datagoed.describe())
# Out:
#              lat        lng
# count  30.000000  30.000000
# mean   52.336034   4.796142
# std     0.056355   0.125296
# min    52.178174   4.565286
# 25%    52.305047   4.659532
# 50%    52.347851   4.856784
# 75%    52.374235   4.893046
# max    52.432369   4.990995

# %%
import pandas
from pandas.plotting import scatter_matrix
import matplotlib.pyplot as plt
from sklearn import model_selection
from sklearn.metrics import classification_report
from sklearn.metrics import confusion_matrix
from sklearn.metrics import accuracy_score
from sklearn.linear_model import LogisticRegression
from sklearn.tree import DecisionTreeClassifier
from sklearn.neighbors import KNeighborsClassifier
from sklearn.discriminant_analysis import LinearDiscriminantAnalysis
from sklearn.naive_bayes import GaussianNB
from sklearn.svm import SVC

# %%
mapmean = folium.Map(location=[52.336034, 4.796142], zoom_start=12) # generate map centred around the Conrad Hotel
# add a red circle marker to represent the Conrad Hotel
folium.features.CircleMarker(
    [52.346447, 4.789998],
    radius=10,
    color='red',
    popup='Conrad Hotel',
    fill = True,
    fill_color = 'red',
    fill_opacity = 0.6
).add_to(mapmean)

mapmean

mapmean
# Out:
# <div style="width:100%;"><div style="position:relative;width:100%;height:0;padding-bottom:60%;"><iframe src="data:text/html;charset=utf-8;base64,..." style="position:absolute;width:100%;height:100%;left:0;top:0;border:none !important;" allowfullscreen webkitallowfullscreen mozallowfullscreen></iframe></div></div>

# %%
datagoed.hist()
plt.show()

# %%
scatter_matrix(datagoed)
plt.show()

# %%
array = dataframe_filtered.values
X = array[:,0:4]
Y = array[:,4]
validation_size = 0.20
lat = 7
X_train, X_validation, Y_train, Y_validation = model_selection.train_test_split(X, Y, test_size=validation_size, random_state=lat)

# %%
lat = 7
scoring = 'accuracy'

# %%
import pandas as pd
import pylab as pl
import numpy as np
import scipy.optimize as opt
from sklearn import preprocessing
# %matplotlib inline 
import matplotlib.pyplot as plt

# %%
feature_cols = ['lat', 'lng']
X = datagoed[feature_cols] # Features
y = datagoed.lng # Target variable

# %%
# split X and y into training and testing sets
from sklearn.model_selection import train_test_split
X_train,X_test,y_train,y_test = train_test_split(X,y,test_size=0.25,random_state=0)
